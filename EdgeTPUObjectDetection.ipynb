# %% [markdown]
# <a href="https://colab.research.google.com/github/trirop/Kayakcounter/blob/master/EdgeTPUObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)
# Out:
# Found GPU at: /device:GPU:0
# 1.15.2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/EdgeTPUObjectDetection/'
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 43048 (delta 16), reused 26 (delta 8), pack-reused 43014
# Receiving objects: 100% (43048/43048), 549.86 MiB | 15.39 MiB/s, done.
# Resolving deltas: 100% (29284/29284), done.
# Checking out files: 100% (1903/1903), done.

# %%
% cd models
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models

# %%
! pwd
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models

# %%
! git config --global user.email "tristan@roppel.de"
! git config --global user.name "Tristan"

# %%
! git reset --hard
# Out:
# fatal: Could not parse object 'HEAD'.

# %%
! git pull origin master
# Out:
# error: refs/heads/master does not point to a valid object!
# error: refs/remotes/origin/HEAD does not point to a valid object!
# error: refs/remotes/origin/MarkDaoust-patch-1 does not point to a valid object!
# error: refs/remotes/origin/archive does not point to a valid object!
# error: refs/remotes/origin/assemblenet does not point to a valid object!
# error: refs/remotes/origin/benchmark does not point to a valid object!
# error: refs/remotes/origin/classifier_multiworker does not point to a valid object!
# error: refs/remotes/origin/delf does not point to a valid object!
# error: refs/remotes/origin/detr does not point to a valid object!
# error: refs/remotes/origin/dynamicwebpaige-patch-1 does not point to a valid object!
# error: refs/remotes/origin/dynamicwebpaige-patch-1-1 does not point to a valid object!
# error: refs/remotes/origin/electra does not point to a valid object!
# error: refs/remotes/origin/jvishnuvardhan-patch-10 does not point to a valid object!
# ...

# %%
! git add .

# %%
! git commit -m "Update done"
# Out:
# [master b70b7a83] Update done
#  32 files changed, 0 insertions(+), 0 deletions(-)
#  mode change 100755 => 100644 official/recommendation/run.sh
#  mode change 100755 => 100644 official/utils/testing/scripts/ci_sanity.sh
#  mode change 100755 => 100644 official/utils/testing/scripts/presubmit.sh
#  mode change 100755 => 100644 research/cognitive_planning/train_supervised_active_vision.sh
#  mode change 100755 => 100644 research/cvt_text/fetch_data.sh
#  mode change 100755 => 100644 research/deep_speech/run_deep_speech.sh
#  mode change 100755 => 100644 research/delf/delf/python/training/download_dataset.sh
#  mode change 100755 => 100644 research/delf/delf/python/training/install_delf.sh
#  mode change 100755 => 100644 research/efficient-hrl/README.md
#  mode change 100755 => 100644 research/efficient-hrl/environments/assets/ant.xml
#  mode change 100755 => 100644 research/lfads/run_lfads.py
#  mode change 100755 => 100644 research/lfads/synth_data/run_generate_synth_data.sh
# ...

# %%
! git checkout f788046ca876a8820e05b0b48c1fc2e16b0955bc
# Out:
# Checking out files: 100% (3398/3398), done.
# Note: checking out 'f788046ca876a8820e05b0b48c1fc2e16b0955bc'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at f788046c Add model_dir to all tests to avoid "resource not found error". (#6143)

# %%
! pwd
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models

# %%
! git clone https://github.com/google-coral/tutorials.git
# Out:
# Cloning into 'tutorials'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 106 (delta 61), reused 87 (delta 42), pack-reused 0
# Receiving objects: 100% (106/106), 57.18 KiB | 813.00 KiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
% cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models

# %%
! pwd
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models

# %%
! cp -r tutorials/docker/object_detection/scripts/* models/research/
# Out:
# cp: target 'models/research/' is not a directory

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# !pip install tf_slim
# !pip install Pillow
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 39 not upgraded.
# Need to get 1,791 kB of archives.
# ...

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research

# %%
import os
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/Kayakcounter/models/research/:/content/gdrive/My Drive/Kayakcounter/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/__init__.py -> build/lib/object_detection
# copying object_detection/eval_util.py -> build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/export_inference_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> build/lib/object_detection
# copying object_detection/exporter.py -> build/lib/object_detection
# copying object_detection/inputs.py -> build/lib/object_detection
# copying object_detection/inputs_test.py -> build/lib/object_detection
# copying object_detection/model_hparams.py -> build/lib/object_detection
# copying object_detection/model_lib.py -> build/lib/object_detection
# ...

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/object_detection/builders/
# !python model_builder_test.py
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/object_detection/builders
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_embedded_ssd_mobilenet_v1_model_from_config
# [       OK ] ModelBuilderTest.test_create_embedded_ssd_mobilenet_v1_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_inception_resnet_v2_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_inception_resnet_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_inception_v2_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_inception_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_nas_model_from_config
# ...

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/object_detection/
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/object_detection

# %%
! pwd
# Out:
# /content

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/tutorials/docker/object_detections/scripts
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/tutorials/docker/object_detections/scripts'
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models/tutorials/docker

# %%
! /bin/bash ./prepare_checkpoint_and_dataset.sh --network_type mobilenet_v1_ssd --train_whole_model false
# Out:
# /bin/bash: ./prepare_checkpoint_and_dataset.sh: No such file or directory

# %%
# %env NUM_TRAINING_STEPS=500
# %env NUM_EVAL_STEPS=100

# If you're retraining the whole model, we suggest thes values:
# %env NUM_TRAINING_STEPS=50000
# %env NUM_EVAL_STEPS=2000

# %%
! /bin/bash ./retrain_detection_model.sh --num_training_steps $NUM_TRAINING_STEPS --num_eval_steps $NUM_EVAL_STEPS

# %%
! /bin/bash ./convert_checkpoint_to_edgetpu_tflite.sh --checkpoint_num $NUM_TRAINING_STEPS

# %%
! curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -

! echo "deb https://packages.cloud.google.com/apt coral-edgetpu-stable main" | sudo tee /etc/apt/sources.list.d/coral-edgetpu.list

! sudo apt-get update

! sudo apt-get install edgetpu-compiler

# %%
# %cd learn_pet/models/

! ls

# %%
! edgetpu_compiler output_tflite_graph.tflite

# %%
from google.colab import files

files.download('output_tflite_graph_edgetpu.tflite')
files.download('labels.txt')
