# %% [markdown]
# <a href="https://colab.research.google.com/github/trirop/Kayakcounter/blob/master/EdgeTPUTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd '/content/gdrive/My Drive/EdgeTPUObjectDetection/'

# %%
# !git clone https://github.com/tensorflow/models.git

# %%
% cd models

# %%
! pwd

# %%
! git config --global user.email "tristan@roppel.de"
! git config --global user.name "Tristan"

# %%
! git reset --hard

# %%
! git pull origin master

# %%
! git add .

# %%
! git commit -m "Update done"

# %%
! git checkout f788046ca876a8820e05b0b48c1fc2e16b0955bc

# %%
! pwd

# %%
! git clone https://github.com/google-coral/tutorials.git

# %%
% cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models

# %%
! pwd

# %%
! cp -r tutorials/docker/object_detection/scripts/* models/research/

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# !pip install tf_slim
# !pip install Pillow

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/Kayakcounter/models/research/:/content/gdrive/My Drive/Kayakcounter/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/object_detection/builders/
# !python model_builder_test.py

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/object_detection/

# %%
! pwd
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research

# %%
# %cd /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research
# Out:
# /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research

# %%
! /bin/bash ./prepare_checkpoint_and_dataset.sh --network_type mobilenet_v1_ssd --train_whole_model false
# Out:
# + network_type=mobilenet_v1_ssd
# + train_whole_model=false
# + [[ 4 -gt 0 ]]
# + case "$1" in
# + network_type=mobilenet_v1_ssd
# + shift 2
# + [[ 2 -gt 0 ]]
# + case "$1" in
# + train_whole_model=false
# + shift 2
# + [[ 0 -gt 0 ]]
# + source '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/constants.sh'
# ++ declare -A ckpt_link_map
# ++ declare -A ckpt_name_map
# ++ declare -A config_filename_map
# ++ ckpt_link_map["mobilenet_v1_ssd"]=http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz
# ++ ckpt_link_map["mobilenet_v2_ssd"]=http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz
# ++ ckpt_name_map["mobilenet_v1_ssd"]=ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18
# ++ ckpt_name_map["mobilenet_v2_ssd"]=ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03
# ++ config_filename_map["mobilenet_v1_ssd-true"]=pipeline_mobilenet_v1_ssd_retrain_whole_model.config
# ++ config_filename_map["mobilenet_v1_ssd-false"]=pipeline_mobilenet_v1_ssd_retrain_last_few_layers.config
# ++ config_filename_map["mobilenet_v2_ssd-true"]=pipeline_mobilenet_v2_ssd_retrain_whole_model.config
# ++ config_filename_map["mobilenet_v2_ssd-false"]=pipeline_mobilenet_v2_ssd_retrain_last_few_layers.config
# ++ INPUT_TENSORS=normalized_input_image_tensor
# ++ OUTPUT_TENSORS=TFLite_Detection_PostProcess,TFLite_Detection_PostProcess:1,TFLite_Detection_PostProcess:2,TFLite_Detection_PostProcess:3
# ++ OBJ_DET_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research'
# ++ LEARN_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet'
# ++ DATASET_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet'
# ++ CKPT_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt'
# ++ TRAIN_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train'
# ++ OUTPUT_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/models'
# + echo 'PREPARING checkpoint...'
# PREPARING checkpoint...
# + mkdir -p '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet'
# + ckpt_link=http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz
# + ckpt_name=ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18
# + cd '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet'
# + wget -O ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz
# --2020-08-31 06:08:00--  http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.20.128, 2607:f8b0:400e:c09::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.20.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85682182 (82M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz’
#
# ssd_mobilenet_v1_qu 100%[===================>]  81.71M  50.6MB/s    in 1.6s
#
# 2020-08-31 06:08:02 (50.6 MB/s) - ‘ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz’ saved [85682182/85682182]
#
# + tar zxvf ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz
# ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18/pipeline.config
# ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18/tflite_graph.pb
# ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18/model.ckpt.meta
# ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18/
# ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18/tflite_graph.pbtxt
# ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18/model.ckpt.index
# ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18/model.ckpt.data-00000-of-00001
# + mv ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18 '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt'
# + echo 'CHOSING config file...'
# CHOSING config file...
# + config_filename=pipeline_mobilenet_v1_ssd_retrain_last_few_layers.config
# + cd '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research'
# + cp configs/pipeline_mobilenet_v1_ssd_retrain_last_few_layers.config '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt/pipeline.config'
# + echo 'REPLACING variables in config file...'
# REPLACING variables in config file...
# + sed -i 's%CKPT_DIR_TO_CONFIGURE%/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt%g' '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt/pipeline.config'
# + sed -i 's%DATASET_DIR_TO_CONFIGURE%/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet%g' '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt/pipeline.config'
# + echo 'PREPARING dataset'
# PREPARING dataset
# + mkdir -p '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet'
# + cd '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet'
# + wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# --2020-08-31 06:08:04--  http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/x-gzip]
# Saving to: ‘images.tar.gz’
#
# images.tar.gz       100%[===================>] 755.23M  22.0MB/s    in 35s
#
# 2020-08-31 06:08:41 (21.3 MB/s) - ‘images.tar.gz’ saved [791918971/791918971]
#
# + wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# --2020-08-31 06:08:41--  http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173078 (18M) [application/x-gzip]
# Saving to: ‘annotations.tar.gz’
#
# annotations.tar.gz  100%[===================>]  18.28M  10.3MB/s    in 1.8s
#
# 2020-08-31 06:09:07 (10.3 MB/s) - ‘annotations.tar.gz’ saved [19173078/19173078]
#
# + tar zxf images.tar.gz
# + tar zxf annotations.tar.gz
# + echo 'PREPARING dataset using first two classes of Oxford-IIIT Pet dataset...'
# PREPARING dataset using first two classes of Oxford-IIIT Pet dataset...
# + cp '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/list.txt' '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/list_petsdataset.txt'
# + cp '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/trainval.txt' '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/trainval_petsdataset.txt'
# + cp '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/test.txt' '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/test_petsdataset.txt'
# + grep Abyssinian '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/list_petsdataset.txt'
# + grep american_bulldog '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/list_petsdataset.txt'
# + grep Abyssinian '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/trainval_petsdataset.txt'
# + grep american_bulldog '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/trainval_petsdataset.txt'
# + grep Abyssinian '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/test_petsdataset.txt'
# + grep american_bulldog '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/test_petsdataset.txt'
# + echo 'PREPARING label map...'
# PREPARING label map...
# + cd '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research'
# + cp object_detection/data/pet_label_map.pbtxt '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet'
# + echo 'CONVERTING dataset to TF Record...'
# CONVERTING dataset to TF Record...
# + python object_detection/dataset_tools/create_pet_tf_record.py '--label_map_path=/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/pet_label_map.pbtxt' '--data_dir=/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet' '--output_dir=/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet'
# WARNING:tensorflow:From object_detection/dataset_tools/create_pet_tf_record.py:318: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# I0831 06:15:02.198817 140454377043840 create_pet_tf_record.py:273] Reading from Pet dataset.
# I0831 06:15:02.200673 140454377043840 create_pet_tf_record.py:288] 140 training and 60 validation examples.
# I0831 06:15:02.361174 140454377043840 create_pet_tf_record.py:241] On image 0 of 140
# WARNING:tensorflow:From object_detection/dataset_tools/create_pet_tf_record.py:248: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0831 06:15:02.362049 140454377043840 module_wrapper.py:139] From object_detection/dataset_tools/create_pet_tf_record.py:248: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/utils/dataset_util.py:79: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   if not xml:
# I0831 06:15:03.385588 140454377043840 create_pet_tf_record.py:241] On image 100 of 140
# W0831 06:15:03.392769 140454377043840 create_pet_tf_record.py:246] Could not find /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet/annotations/xmls/Abyssinian_104.xml, ignoring example.
# I0831 06:15:03.698471 140454377043840 create_pet_tf_record.py:241] On image 0 of 60

# %%
# %env NUM_TRAINING_STEPS=500
# %env NUM_EVAL_STEPS=100

# If you're retraining the whole model, we suggest thes values:
# %env NUM_TRAINING_STEPS=50000
# %env NUM_EVAL_STEPS=2000
# Out:
# env: NUM_TRAINING_STEPS=500
# env: NUM_EVAL_STEPS=100

# %%
! /bin/bash ./retrain_detection_model.sh --num_training_steps $NUM_TRAINING_STEPS --num_eval_steps $NUM_EVAL_STEPS
# Out:
# + num_training_steps=500
# + [[ 4 -gt 0 ]]
# + case "$1" in
# + num_training_steps=500
# + shift 2
# + [[ 2 -gt 0 ]]
# + case "$1" in
# + num_eval_steps=100
# + shift 2
# + [[ 0 -gt 0 ]]
# + source '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/constants.sh'
# ++ declare -A ckpt_link_map
# ++ declare -A ckpt_name_map
# ++ declare -A config_filename_map
# ++ ckpt_link_map["mobilenet_v1_ssd"]=http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18.tar.gz
# ++ ckpt_link_map["mobilenet_v2_ssd"]=http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz
# ++ ckpt_name_map["mobilenet_v1_ssd"]=ssd_mobilenet_v1_quantized_300x300_coco14_sync_2018_07_18
# ++ ckpt_name_map["mobilenet_v2_ssd"]=ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03
# ++ config_filename_map["mobilenet_v1_ssd-true"]=pipeline_mobilenet_v1_ssd_retrain_whole_model.config
# ++ config_filename_map["mobilenet_v1_ssd-false"]=pipeline_mobilenet_v1_ssd_retrain_last_few_layers.config
# ++ config_filename_map["mobilenet_v2_ssd-true"]=pipeline_mobilenet_v2_ssd_retrain_whole_model.config
# ++ config_filename_map["mobilenet_v2_ssd-false"]=pipeline_mobilenet_v2_ssd_retrain_last_few_layers.config
# ++ INPUT_TENSORS=normalized_input_image_tensor
# ++ OUTPUT_TENSORS=TFLite_Detection_PostProcess,TFLite_Detection_PostProcess:1,TFLite_Detection_PostProcess:2,TFLite_Detection_PostProcess:3
# ++ OBJ_DET_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research'
# ++ LEARN_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet'
# ++ DATASET_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/pet'
# ++ CKPT_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt'
# ++ TRAIN_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train'
# ++ OUTPUT_DIR='/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/models'
# + mkdir -p '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train'
# + python object_detection/model_main.py '--pipeline_config_path=/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/ckpt/pipeline.config' '--model_dir=/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train' --num_train_steps=500 --num_eval_steps=100
# WARNING:tensorflow:From object_detection/model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0831 06:20:45.870145 140435491186560 model_lib.py:758] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting train_steps: 500
# I0831 06:20:45.870371 140435491186560 config_util.py:552] Maybe overwriting train_steps: 500
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0831 06:20:45.870477 140435491186560 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I0831 06:20:45.870558 140435491186560 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0831 06:20:45.870640 140435491186560 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# INFO:tensorflow:Maybe overwriting load_pretrained: True
# I0831 06:20:45.870716 140435491186560 config_util.py:552] Maybe overwriting load_pretrained: True
# INFO:tensorflow:Ignoring config override key: load_pretrained
# I0831 06:20:45.870790 140435491186560 config_util.py:562] Ignoring config override key: load_pretrained
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0831 06:20:45.871607 140435491186560 model_lib.py:774] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:create_estimator_and_inputs: use_tpu False, export_to_tpu False
# I0831 06:20:45.871735 140435491186560 model_lib.py:809] create_estimator_and_inputs: use_tpu False, export_to_tpu False
# INFO:tensorflow:Using config: {'_model_dir': '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fb9632d05f8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I0831 06:20:45.872277 140435491186560 estimator.py:212] Using config: {'_model_dir': '/content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fb9632d05f8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7fb943eb5ae8>) includes params argument, but params are not passed to Estimator.
# W0831 06:20:45.872507 140435491186560 model_fn.py:630] Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7fb943eb5ae8>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Not using Distribute Coordinator.
# I0831 06:20:45.873185 140435491186560 estimator_training.py:186] Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# I0831 06:20:45.873358 140435491186560 training.py:612] Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# I0831 06:20:45.873571 140435491186560 training.py:700] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0831 06:20:45.881592 140435491186560 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:num_readers has been reduced to 10 to match input file shards.
# W0831 06:20:45.928850 140435491186560 dataset_builder.py:83] num_readers has been reduced to 10 to match input file shards.
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# W0831 06:20:45.934130 140435491186560 deprecation.py:323] From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/builders/dataset_builder.py:175: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0831 06:20:45.953583 140435491186560 deprecation.py:323] From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/builders/dataset_builder.py:175: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fb943eb8d30>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0831 06:20:46.244782 140435491186560 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fb943eb8d30>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function train_input.<locals>.transform_and_pad_input_data_fn at 0x7fb9635e4d90> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0831 06:20:46.439280 140435491186560 ag_logging.py:146] Entity <function train_input.<locals>.transform_and_pad_input_data_fn at 0x7fb9635e4d90> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/inputs.py:80: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0831 06:20:46.444617 140435491186560 deprecation.py:323] From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/inputs.py:80: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0831 06:20:46.451654 140435491186560 deprecation.py:323] From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/core/preprocessor.py:199: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0831 06:20:46.545377 140435491186560 deprecation.py:323] From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/core/preprocessor.py:199: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/inputs.py:261: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0831 06:20:47.409598 140435491186560 deprecation.py:323] From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/inputs.py:261: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Calling model_fn.
# I0831 06:20:47.874556 140435491186560 estimator.py:1148] Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0831 06:20:47.899338 140435491186560 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:20:49.563927 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:20:49.593506 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:20:49.622830 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:20:49.651020 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:20:49.679561 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:20:49.708589 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# W0831 06:20:49.746458 140435491186560 variables_helper.py:153] Variable [BoxPredictor_0/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[273]], model variable shape: [[9]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.746573 140435491186560 variables_helper.py:153] Variable [BoxPredictor_0/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1, 1, 512, 273]], model variable shape: [[1, 1, 512, 9]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.746666 140435491186560 variables_helper.py:153] Variable [BoxPredictor_1/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[546]], model variable shape: [[18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.746731 140435491186560 variables_helper.py:153] Variable [BoxPredictor_1/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1, 1, 1024, 546]], model variable shape: [[1, 1, 1024, 18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.746827 140435491186560 variables_helper.py:153] Variable [BoxPredictor_2/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[546]], model variable shape: [[18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.746888 140435491186560 variables_helper.py:153] Variable [BoxPredictor_2/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1, 1, 512, 546]], model variable shape: [[1, 1, 512, 18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.746979 140435491186560 variables_helper.py:153] Variable [BoxPredictor_3/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[546]], model variable shape: [[18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.747041 140435491186560 variables_helper.py:153] Variable [BoxPredictor_3/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1, 1, 256, 546]], model variable shape: [[1, 1, 256, 18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.747152 140435491186560 variables_helper.py:153] Variable [BoxPredictor_4/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[546]], model variable shape: [[18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.747213 140435491186560 variables_helper.py:153] Variable [BoxPredictor_4/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1, 1, 256, 546]], model variable shape: [[1, 1, 256, 18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.747298 140435491186560 variables_helper.py:153] Variable [BoxPredictor_5/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[546]], model variable shape: [[18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.747363 140435491186560 variables_helper.py:153] Variable [BoxPredictor_5/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1, 1, 128, 546]], model variable shape: [[1, 1, 128, 18]]. This variable will not be initialized from the checkpoint.
# W0831 06:20:49.749196 140435491186560 variables_helper.py:156] Variable [global_step] is not available in checkpoint
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_0/add_fold
# I0831 06:21:16.985060 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_0/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/add_fold
# I0831 06:21:16.985568 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/add_fold
# I0831 06:21:16.985907 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/add_fold
# I0831 06:21:16.986256 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/add_fold
# I0831 06:21:16.986586 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/add_fold
# I0831 06:21:16.986931 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/add_fold
# I0831 06:21:16.987284 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/add_fold
# I0831 06:21:16.987658 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/add_fold
# I0831 06:21:16.987977 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/add_fold
# I0831 06:21:16.988301 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/add_fold
# I0831 06:21:16.988600 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/add_fold
# I0831 06:21:16.988909 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/add_fold
# I0831 06:21:16.989257 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/add_fold
# I0831 06:21:16.989583 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/add_fold
# I0831 06:21:16.989897 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/add_fold
# I0831 06:21:16.990245 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/add_fold
# I0831 06:21:16.990572 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/add_fold
# I0831 06:21:16.990874 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/add_fold
# I0831 06:21:16.991185 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/add_fold
# I0831 06:21:16.991521 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/add_fold
# I0831 06:21:16.991841 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/add_fold
# I0831 06:21:16.992180 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/add_fold
# I0831 06:21:16.992501 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/add_fold
# I0831 06:21:16.992810 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/add_fold
# I0831 06:21:16.993122 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/add_fold
# I0831 06:21:16.993432 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/add_fold
# I0831 06:21:16.993718 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/add_fold
# INFO:tensorflow:Done calling model_fn.
# I0831 06:21:20.451288 140435491186560 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# I0831 06:21:20.452632 140435491186560 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# I0831 06:21:25.487240 140435491186560 monitored_session.py:240] Graph was finalized.
# 2020-08-31 06:21:25.492620: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-08-31 06:21:25.492842: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x243e6000 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-31 06:21:25.492877: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-31 06:21:25.496164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-31 06:21:25.593258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:21:25.593939: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x243e5d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-31 06:21:25.593997: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-08-31 06:21:25.594267: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:21:25.594820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-31 06:21:25.595190: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-31 06:21:25.606374: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-31 06:21:25.611964: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-31 06:21:25.617739: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-31 06:21:25.628977: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-31 06:21:25.632474: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-31 06:21:25.645528: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-31 06:21:25.645663: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:21:25.646261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:21:25.646790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-31 06:21:25.646916: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-31 06:21:25.648089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-31 06:21:25.648119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-31 06:21:25.648139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-31 06:21:25.648262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:21:25.648864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:21:25.649428: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-31 06:21:25.649469: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14125 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Running local_init_op.
# I0831 06:21:36.923802 140435491186560 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0831 06:21:37.595710 140435491186560 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt.
# I0831 06:21:53.899475 140435491186560 basic_session_run_hooks.py:606] Saving checkpoints for 0 into /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt.
# 2020-08-31 06:22:07.758498: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 26214400 exceeds 10% of system memory.
# 2020-08-31 06:22:07.801800: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 26214400 exceeds 10% of system memory.
# 2020-08-31 06:22:17.739135: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 94633984 exceeds 10% of system memory.
# 2020-08-31 06:22:17.762579: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 26214400 exceeds 10% of system memory.
# 2020-08-31 06:22:17.777510: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 52428800 exceeds 10% of system memory.
# 2020-08-31 06:22:20.647060: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-31 06:22:27.088013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# INFO:tensorflow:loss = 3.841269, step = 0
# I0831 06:22:40.283530 140435491186560 basic_session_run_hooks.py:262] loss = 3.841269, step = 0
# INFO:tensorflow:global_step/sec: 0.561656
# I0831 06:25:38.327542 140435491186560 basic_session_run_hooks.py:692] global_step/sec: 0.561656
# INFO:tensorflow:loss = 0.24384291, step = 100 (178.046 sec)
# I0831 06:25:38.329498 140435491186560 basic_session_run_hooks.py:260] loss = 0.24384291, step = 100 (178.046 sec)
# INFO:tensorflow:global_step/sec: 0.643722
# I0831 06:28:13.673888 140435491186560 basic_session_run_hooks.py:692] global_step/sec: 0.643722
# INFO:tensorflow:loss = 0.23348825, step = 200 (155.346 sec)
# I0831 06:28:13.675802 140435491186560 basic_session_run_hooks.py:260] loss = 0.23348825, step = 200 (155.346 sec)
# INFO:tensorflow:global_step/sec: 0.646667
# I0831 06:30:48.313106 140435491186560 basic_session_run_hooks.py:692] global_step/sec: 0.646667
# INFO:tensorflow:loss = 0.19830261, step = 300 (154.639 sec)
# I0831 06:30:48.314658 140435491186560 basic_session_run_hooks.py:260] loss = 0.19830261, step = 300 (154.639 sec)
# INFO:tensorflow:Saving checkpoints for 343 into /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt.
# I0831 06:31:57.952280 140435491186560 basic_session_run_hooks.py:606] Saving checkpoints for 343 into /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fb92c18def0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0831 06:32:00.862061 140435491186560 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fb92c18def0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fb92c18c0d0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0831 06:32:01.041150 140435491186560 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fb92c18c0d0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0831 06:32:01.554893 140435491186560 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:32:03.220424 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:32:03.249666 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:32:03.277914 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:32:03.305717 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:32:03.334001 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:32:03.362094 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_0/add_fold
# I0831 06:32:04.891247 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_0/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/add_fold
# I0831 06:32:04.891560 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/add_fold
# I0831 06:32:04.891742 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/add_fold
# I0831 06:32:04.891920 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/add_fold
# I0831 06:32:04.892103 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/add_fold
# I0831 06:32:04.892282 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/add_fold
# I0831 06:32:04.892450 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/add_fold
# I0831 06:32:04.892629 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/add_fold
# I0831 06:32:04.892796 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/add_fold
# I0831 06:32:04.892967 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/add_fold
# I0831 06:32:04.893143 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/add_fold
# I0831 06:32:04.893318 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/add_fold
# I0831 06:32:04.893481 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/add_fold
# I0831 06:32:04.893657 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/add_fold
# I0831 06:32:04.893820 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/add_fold
# I0831 06:32:04.893987 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/add_fold
# I0831 06:32:04.894163 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/add_fold
# I0831 06:32:04.894334 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/add_fold
# I0831 06:32:04.894505 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/add_fold
# I0831 06:32:04.894675 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/add_fold
# I0831 06:32:04.894851 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/add_fold
# I0831 06:32:04.895031 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/add_fold
# I0831 06:32:04.895222 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/add_fold
# I0831 06:32:04.895412 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/add_fold
# I0831 06:32:04.895587 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/add_fold
# I0831 06:32:04.895764 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/add_fold
# I0831 06:32:04.895935 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_2_1x1_256/add_fold
# I0831 06:32:04.896123 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_2_1x1_256/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_2_3x3_s2_512/add_fold
# I0831 06:32:04.896315 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_2_3x3_s2_512/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_3_1x1_128/add_fold
# I0831 06:32:04.896485 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_3_1x1_128/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_3_3x3_s2_256/add_fold
# I0831 06:32:04.896659 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_3_3x3_s2_256/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_4_1x1_128/add_fold
# I0831 06:32:04.896830 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_4_1x1_128/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_4_3x3_s2_256/add_fold
# I0831 06:32:04.896999 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_4_3x3_s2_256/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_5_1x1_64/add_fold
# I0831 06:32:04.897178 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_5_1x1_64/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_5_3x3_s2_128/add_fold
# I0831 06:32:04.897352 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_5_3x3_s2_128/add_fold
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/eval_util.py:855: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0831 06:32:04.923885 140435491186560 deprecation.py:323] From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/eval_util.py:855: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/Kayakcounter/models/research/object_detection/utils/visualization_utils.py:618: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
# ...
# I0831 06:36:24.278355 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_4_3x3_s2_256/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_5_1x1_64/add_fold
# I0831 06:36:24.278544 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_1_Conv2d_5_1x1_64/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_5_3x3_s2_128/add_fold
# I0831 06:36:24.278731 140435491186560 quantize.py:299] Skipping quant after FeatureExtractor/MobilenetV1/Conv2d_13_pointwise_2_Conv2d_5_3x3_s2_128/add_fold
# INFO:tensorflow:Done calling model_fn.
# I0831 06:36:25.054569 140435491186560 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-08-31T06:36:25Z
# I0831 06:36:25.070452 140435491186560 evaluation.py:255] Starting evaluation at 2020-08-31T06:36:25Z
# INFO:tensorflow:Graph was finalized.
# I0831 06:36:25.606423 140435491186560 monitored_session.py:240] Graph was finalized.
# 2020-08-31 06:36:25.607377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:25.607724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-31 06:36:25.607819: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-31 06:36:25.607845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-31 06:36:25.607867: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-31 06:36:25.607889: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-31 06:36:25.607909: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-31 06:36:25.607928: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-31 06:36:25.607949: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-31 06:36:25.608052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:25.608391: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:25.608642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-31 06:36:25.608686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-31 06:36:25.608699: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-31 06:36:25.608708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-31 06:36:25.608807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:25.609103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:25.609349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14125 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt-500
# I0831 06:36:25.612417 140435491186560 saver.py:1284] Restoring parameters from /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# I0831 06:36:26.614093 140435491186560 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0831 06:36:26.744506 140435491186560 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 60 images.
# I0831 06:36:31.213156 140433098135296 coco_evaluation.py:237] Performing evaluation on 60 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0831 06:36:31.213787 140433098135296 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0831 06:36:31.218310 140433098135296 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.35s).
# Accumulating evaluation results...
# DONE (t=0.08s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.679
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.783
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.433
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.731
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.709
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.731
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.731
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.786
# INFO:tensorflow:Finished evaluation at 2020-08-31-06:36:32
# I0831 06:36:32.085819 140435491186560 evaluation.py:275] Finished evaluation at 2020-08-31-06:36:32
# INFO:tensorflow:Saving dict for global step 500: DetectionBoxes_Precision/mAP = 0.679415, DetectionBoxes_Precision/mAP (large) = 0.73140854, DetectionBoxes_Precision/mAP (medium) = 0.43316832, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.929957, DetectionBoxes_Precision/mAP@.75IOU = 0.7827208, DetectionBoxes_Recall/AR@1 = 0.7088571, DetectionBoxes_Recall/AR@10 = 0.73085713, DetectionBoxes_Recall/AR@100 = 0.73085713, DetectionBoxes_Recall/AR@100 (large) = 0.78571427, DetectionBoxes_Recall/AR@100 (medium) = 0.4547619, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/classification_loss = 0.35928747, Loss/localization_loss = 0.09374569, Loss/regularization_loss = 0.117687814, Loss/total_loss = 0.5707209, global_step = 500, learning_rate = 0.11736482, loss = 0.5707209
# I0831 06:36:32.086167 140435491186560 estimator.py:2049] Saving dict for global step 500: DetectionBoxes_Precision/mAP = 0.679415, DetectionBoxes_Precision/mAP (large) = 0.73140854, DetectionBoxes_Precision/mAP (medium) = 0.43316832, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.929957, DetectionBoxes_Precision/mAP@.75IOU = 0.7827208, DetectionBoxes_Recall/AR@1 = 0.7088571, DetectionBoxes_Recall/AR@10 = 0.73085713, DetectionBoxes_Recall/AR@100 = 0.73085713, DetectionBoxes_Recall/AR@100 (large) = 0.78571427, DetectionBoxes_Recall/AR@100 (medium) = 0.4547619, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/classification_loss = 0.35928747, Loss/localization_loss = 0.09374569, Loss/regularization_loss = 0.117687814, Loss/total_loss = 0.5707209, global_step = 500, learning_rate = 0.11736482, loss = 0.5707209
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt-500
# I0831 06:36:32.096130 140435491186560 estimator.py:2109] Saving 'checkpoint_path' summary for global step 500: /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt-500
# INFO:tensorflow:Performing the final export in the end of training.
# I0831 06:36:32.098088 140435491186560 exporter.py:410] Performing the final export in the end of training.
# INFO:tensorflow:Calling model_fn.
# I0831 06:36:32.369421 140435491186560 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:36:34.222568 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:36:34.259255 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:36:34.288593 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:36:34.316686 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:36:34.345803 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0831 06:36:34.373795 140435491186560 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0831 06:36:34.955173 140435491186560 estimator.py:1150] Done calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0831 06:36:34.955515 140435491186560 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0831 06:36:34.956195 140435491186560 export_utils.py:170] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0831 06:36:34.956312 140435491186560 export_utils.py:170] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# I0831 06:36:34.956391 140435491186560 export_utils.py:170] Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I0831 06:36:34.956458 140435491186560 export_utils.py:170] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I0831 06:36:34.956551 140435491186560 export_utils.py:170] Signatures INCLUDED in export for Eval: None
# 2020-08-31 06:36:34.957193: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:34.957641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-31 06:36:34.957761: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-31 06:36:34.957801: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-31 06:36:34.957825: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-31 06:36:34.957860: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-31 06:36:34.957879: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-31 06:36:34.957902: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-31 06:36:34.957925: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-31 06:36:34.958019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:34.958360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:34.958598: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-31 06:36:34.958642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-31 06:36:34.958669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-31 06:36:34.958679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-31 06:36:34.958775: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:34.959066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-31 06:36:34.959360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14125 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt-500
# I0831 06:36:34.963518 140435491186560 saver.py:1284] Restoring parameters from /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/model.ckpt-500
# INFO:tensorflow:Assets added to graph.
# I0831 06:36:35.320884 140435491186560 builder_impl.py:665] Assets added to graph.
# INFO:tensorflow:No assets to write.
# I0831 06:36:35.321140 140435491186560 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/export/Servo/temp-b'1598855792'/saved_model.pb
# I0831 06:36:36.009232 140435491186560 builder_impl.py:425] SavedModel written to: /content/gdrive/My Drive/EdgeTPUObjectDetection/models/research/learn_pet/train/export/Servo/temp-b'1598855792'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.19012135.
# I0831 06:36:36.609470 140435491186560 estimator.py:371] Loss for final step: 0.19012135.

# %%
! /bin/bash ./convert_checkpoint_to_edgetpu_tflite.sh --checkpoint_num $NUM_TRAINING_STEPS

# %%
! curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -

! echo "deb https://packages.cloud.google.com/apt coral-edgetpu-stable main" | sudo tee /etc/apt/sources.list.d/coral-edgetpu.list

! sudo apt-get update

! sudo apt-get install edgetpu-compiler

# %%
# %cd learn_pet/models/

! ls

# %%
from google.colab import files

files.download('output_tflite_graph_edgetpu.tflite')
files.download('labels.txt')
